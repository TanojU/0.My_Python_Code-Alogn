# %% [markdown]
# **Three Cup Monte**

# %% [markdown]
# Example of the shuffle function

# %%
#Example of shuffling a list
example = [1,2,3,4,5,6,7]

# %%
from random import shuffle

# %%
shuffle(example) #suffels inplace

# %%
example
# Out:
# [3, 5, 7, 6, 4, 2, 1]

# %% [markdown]
# Three Cup Monte

# %%
#Crate a function for returning a shuffled list

def shuffle_list(mylist):
    shuffle(mylist)
    return mylist

# %%
#Assign example list to the shuffle function
result = shuffle_list(example)

# %%
result
# Out:
# [4, 5, 2, 3, 1, 6, 7]

# %%
#Creating a list to represent the 3 balls
mylist = [' ', 'O', ' ']

# %%
#To shuffle the list
shuffle_list(mylist)
# Out:
# [' ', ' ', 'O']

# %%
#Create a function to take in the player’s guesses 

def player_guess():
    
    guess='' #Empty guess - this is a placeholder to take in the palyer's guess
    
    while guess not in ['0', '1', '2']:
        guess = input("pick a number: 0, 1 or 2 ") #Note that input ALWAYS returns a STRING
        
    return int(guess)

# %%
player_guess()
# Out:
# pick a number: 0, 1 or 2 8
# pick a number: 0, 1 or 2 3
# pick a number: 0, 1 or 2 1
# 1

# %%
#Save the returned value of player_guess
myindex = player_guess()
# Out:
# pick a number: 0, 1 or 2 2

# %%
myindex
# Out:
# 2

# %%
#Created a function to combine the shuffled list with player's guess
#to check if the players guess was correct or not
#this is where the functions interact with each other
##mylist from shuffle_list AND
##guess from player_guess


def check_guess(mylist,guess):
    if mylist[guess] == 'O': #Check if the 'O' at the position on mylist matches matches the imput value of the guess
        print("Correct!")
    else:
        print("Wrong guess!")
        print (mylist) #show the positing of the 'O' in mylist

# %% [markdown]
# *Calling the functions in the correct order*

# %%
#Setup the logic as a final script to run the functions

# %%
#1 Create the initial list
mylist = [' ', 'O', ' ']

#2 Shuffle the initial list
mixedup_list = shuffle_list(mylist)

#3 Have the user guess the location
guess = player_guess()

#4 Check the list against the user's guess
check_guess(mixedup_list, guess) #this function takes in the results of the other two functions
# Out:
# pick a number: 0, 1 or 2 1
# Wrong guess!
# [' ', ' ', 'O']
